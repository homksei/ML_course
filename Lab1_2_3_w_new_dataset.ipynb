# %% [markdown]
# # Описание базы Crowdsourced Mapping
#
# ### Имеется набор данных для исследовательского анализа данных (EDA) и тестирования простых моделей прогнозирования. Это набор данных игрушек и он состоит из 150000 строк и 6 столбцов.
#
#
#
#
# # Быстрый старт в анализ данных
#
# **с помощью `Pandas` и `Scikit-learn`,**
# **а также `numpy` и `matplotlib`**
#
# - `numpy` – матричные операции
# - `matplotlib` – научная графика
# - `pandas` – таблицы (DataFrame) для анализа данных
# - `scikit-learn` – алгоритмы машинного обучения

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ##### Загружааем файл:

# %%
data = pd.read_csv('./P_ds/toy_dataset.csv', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### Смотрим на таблицу из файла:

# %%
data
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# 5            6  Dallas  Female   36   50786.0      No
# 6            7  Dallas  Female   32   33155.0      No
# 7            8  Dallas    Male   39   30914.0      No
# 8            9  Dallas    Male   51   68667.0      No
# 9           10  Dallas  Female   30   50082.0      No
# 10          11  Dallas  Female   48   41524.0     Yes
# 11          12  Dallas    Male   47   54777.0      No
# 12          13  Dallas    Male   46   62749.0      No
# 13          14  Dallas  Female   42   50894.0      No
# 14          15  Dallas  Female   61   38429.0      No
# 15          16  Dallas    Male   43   34074.0      No
# ...

# %%
print(data)
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# 5            6  Dallas  Female   36   50786.0      No
# 6            7  Dallas  Female   32   33155.0      No
# 7            8  Dallas    Male   39   30914.0      No
# 8            9  Dallas    Male   51   68667.0      No
# 9           10  Dallas  Female   30   50082.0      No
# 10          11  Dallas  Female   48   41524.0     Yes
# 11          12  Dallas    Male   47   54777.0      No
# 12          13  Dallas    Male   46   62749.0      No
# 13          14  Dallas  Female   42   50894.0      No
# 14          15  Dallas  Female   61   38429.0      No
# 15          16  Dallas    Male   43   34074.0      No
# ...

# %% [markdown]
# ##### Посмотрим на начало таблицы:

# %%
data.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %% [markdown]
# ##### Смотрим на конец таблицы:

# %%
data.tail()
# Out:
#         Number    City  Gender  Age    Income Illness
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No

# %% [markdown]
# ## Описание классов и признаков
#
#  - `Number`: A simple index number for each row
#
#  - `City`: The location of a person (Dallas, New York City, Los Angeles, Mountain View, Boston, Washington D.C., San Diego and Austin)
#
#  - `Gender`: Gender of a person (Male or Female)
#
#  - `Age`: The age of a person (Ranging from 25 to 65 years)
#
#  - `Income`: Annual income of a person (Ranging from -674 to 177175)
#
#  - `Illness`: Is the person Ill? (Yes or No)

# %% [markdown]
# ##### Смотрим на размерность датасета и изучаем названия столбцов (описание каждого выше).

# %%
print(data.shape)
print(data.columns)
# Out:
# (150000, 6)
# Index(['Number', 'City', 'Gender', 'Age', 'Income', 'Illness'], dtype='object')

# %% [markdown]
# ##### Смотрим на диапазоны индексов

# %%
data.index
# Out:
# RangeIndex(start=0, stop=150000, step=1)

# %% [markdown]
# ##### "Вытаскиваем" из таблицы конкретные элементы:

# %%
data.at[2, 'Income']
# Out:
# 52483.0

# %% [markdown]
# ##### Смотрим на конкретные столбцы (столбцы значений признаков):

# %%
data['Income']
# Out:
# 0          40367.0
# 1          45084.0
# 2          52483.0
# 3          40941.0
# 4          50289.0
# 5          50786.0
# 6          33155.0
# 7          30914.0
# 8          68667.0
# 9          50082.0
# 10         41524.0
# 11         54777.0
# 12         62749.0
# 13         50894.0
# 14         38429.0
# 15         34074.0
# 16         50398.0
# 17         46373.0
# 18         51137.0
# 19         23688.0
# 20         17378.0
# 21         45919.0
# 22         23001.0
# 23         34292.0
# 24         55190.0
# 25         26169.0
# 26         57322.0
# 27         61704.0
# 28         53619.0
# 29         47421.0
#             ...
# 149970     99950.0
# 149971     76928.0
# 149972     84395.0
# 149973     77272.0
# 149974     90430.0
# 149975     92132.0
# 149976     91519.0
# 149977    107123.0
# 149978    100949.0
# 149979     86737.0
# 149980     89384.0
# 149981     77134.0
# 149982     92157.0
# 149983     92482.0
# 149984     99075.0
# 149985     74947.0
# ...

# %% [markdown]
# ##### Обращение к элементам таблицы:

# %%
data['Income'][3]
# Out:
# 40941.0

# %% [markdown]
# ##### Смотрим на различные типы элементов:

# %%
data['Gender'].dtype.name
# Out:
# 'object'

# %%
type(data['Income'][3])
# Out:
# numpy.float64

# %%
type(data['Age'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### Берем кусок таблицы и печатаем ее начало:

# %%
data[['Age', 'Income']].head()
# Out:
#    Age   Income
# 0   41  40367.0
# 1   54  45084.0
# 2   42  52483.0
# 3   40  40941.0
# 4   46  50289.0

# %% [markdown]
# ##### Смотрим основные статистические характеристики по каждому числовому признаку:

# %%
data.describe()
# Out:
#               Number            Age         Income
# count  150000.000000  150000.000000  150000.000000
# mean    75000.500000      44.950200   91252.798273
# std     43301.414527      11.572486   24989.500948
# min         1.000000      25.000000    -654.000000
# 25%     37500.750000      35.000000   80867.750000
# 50%     75000.500000      45.000000   93655.000000
# 75%    112500.250000      55.000000  104519.000000
# max    150000.000000      65.000000  177157.000000

# %% [markdown]
# ##### Смотрим на зависимость признаков друг от друга:

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (30, 30))
pass

# %% [markdown]
# ##### Смотрим на попарную корреляцию признаков:

# %%
data.corr()
# Out:
#           Number       Age    Income
# Number  1.000000 -0.003448  0.410460
# Age    -0.003448  1.000000 -0.001318
# Income  0.410460 -0.001318  1.000000

# %% [markdown]
# ##### Отдельные графики коррелируемых признаков (`Age` и `Income`):

# %%
plt.plot(data['Age'], data['Income'], 'o', alpha = 0.1)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Age vs Income')
pass

# %% [markdown]
# ##### проверка на принадлежность элементов столбца к заданному классу:

# %%
data['Gender'] == 'Male'
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5         False
# 6         False
# 7          True
# 8          True
# 9         False
# 10        False
# 11         True
# 12         True
# 13        False
# 14        False
# 15         True
# 16         True
# 17         True
# 18         True
# 19        False
# 20         True
# 21         True
# 22        False
# 23        False
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 149970    False
# 149971    False
# 149972     True
# 149973    False
# 149974    False
# 149975    False
# 149976     True
# 149977     True
# 149978     True
# 149979     True
# 149980    False
# 149981     True
# 149982    False
# 149983    False
# 149984     True
# 149985    False
# 149986    False
# 149987    False
# 149988    False
# 149989     True
# 149990    False
# 149991     True
# 149992     True
# 149993     True
# ...

# %% [markdown]
# ##### Точечная диаграмма зависимости 2 признаков (`Age` и `Income`) с обозначение принадлежности к классам:

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['Gender'] == 'Male']['Age'],
            data[data['Gender'] == 'Male']['Income'],
            alpha = 0.3,
            label = 'Male',
            color = 'b')

plt.scatter(data[data['Gender'] == 'Female']['Age'],
            data[data['Gender'] == 'Female']['Income'],
            alpha = 0.3,
            label = 'Female',
            color = 'r')



plt.xlabel('Age')
plt.ylabel('Income')
plt.legend()
plt.grid()

# %% [markdown]
# ##### Краткая характеристика номинальных признаков:

# %%
data.describe(include = ['object'])
# Out:
#                  City  Gender Illness
# count          150000  150000  150000
# unique              8       2       2
# top     New York City    Male      No
# freq            50307   83800  137861

# %% [markdown]
# ##### Описание всех признаков вместе:

# %%
data.describe(include = 'all')
# Out:
#                Number           City  Gender            Age         Income  \
# count   150000.000000         150000  150000  150000.000000  150000.000000
# unique            NaN              8       2            NaN            NaN
# top               NaN  New York City    Male            NaN            NaN
# freq              NaN          50307   83800            NaN            NaN
# mean     75000.500000            NaN     NaN      44.950200   91252.798273
# std      43301.414527            NaN     NaN      11.572486   24989.500948
# min          1.000000            NaN     NaN      25.000000    -654.000000
# 25%      37500.750000            NaN     NaN      35.000000   80867.750000
# 50%      75000.500000            NaN     NaN      45.000000   93655.000000
# 75%     112500.250000            NaN     NaN      55.000000  104519.000000
# max     150000.000000            NaN     NaN      65.000000  177157.000000
#
#        Illness
# count   150000
# unique       2
# top         No
# ...

# %% [markdown]
# ##### Список всех возможных вариантов класса `City`:

# %%
data['City'].unique()
# Out:
# array(['Dallas', 'New York City', 'Los Angeles', 'Mountain View',
#        'Boston', 'Washington D.C.', 'San Diego', 'Austin'], dtype=object)

# %% [markdown]
# ##### `Age` у первых представителей каждого класса:

# %%
for name in data['City'].unique():
    print(name, data['Age'][data['City'] == name].iloc[0])
# Out:
# Dallas 41
# New York City 49
# Los Angeles 34
# Mountain View 31
# Boston 57
# Washington D.C. 38
# San Diego 39
# Austin 53

# %% [markdown]
# ## Задача

# %% [markdown]
# #### Уберем столбец `Number`

# %%
data=data.drop(['Number'], axis = 1)

# %%
data
# Out:
#           City  Gender  Age    Income Illness
# 0       Dallas    Male   41   40367.0      No
# 1       Dallas    Male   54   45084.0      No
# 2       Dallas    Male   42   52483.0      No
# 3       Dallas    Male   40   40941.0      No
# 4       Dallas    Male   46   50289.0      No
# 5       Dallas  Female   36   50786.0      No
# 6       Dallas  Female   32   33155.0      No
# 7       Dallas    Male   39   30914.0      No
# 8       Dallas    Male   51   68667.0      No
# 9       Dallas  Female   30   50082.0      No
# 10      Dallas  Female   48   41524.0     Yes
# 11      Dallas    Male   47   54777.0      No
# 12      Dallas    Male   46   62749.0      No
# 13      Dallas  Female   42   50894.0      No
# 14      Dallas  Female   61   38429.0      No
# 15      Dallas    Male   43   34074.0      No
# 16      Dallas    Male   27   50398.0      No
# 17      Dallas    Male   38   46373.0     Yes
# 18      Dallas    Male   47   51137.0      No
# ...

# %% [markdown]
# # Готовим данные

# %% [markdown]
# ##### Смотрим типы признаков и разбиваем их на количественные и номинальные

# %%
data['City'].dtype.name
# Out:
# 'object'

# %%
data['Age'].dtype.name
# Out:
# 'int64'

# %%
data['Gender'].dtype.name
# Out:
# 'object'

# %%
data['Income'].dtype.name
# Out:
# 'float64'

# %%
data['Illness'].dtype.name
# Out:
# 'object'

# %%
data
# Out:
#           City  Gender  Age    Income Illness
# 0       Dallas    Male   41   40367.0      No
# 1       Dallas    Male   54   45084.0      No
# 2       Dallas    Male   42   52483.0      No
# 3       Dallas    Male   40   40941.0      No
# 4       Dallas    Male   46   50289.0      No
# 5       Dallas  Female   36   50786.0      No
# 6       Dallas  Female   32   33155.0      No
# 7       Dallas    Male   39   30914.0      No
# 8       Dallas    Male   51   68667.0      No
# 9       Dallas  Female   30   50082.0      No
# 10      Dallas  Female   48   41524.0     Yes
# 11      Dallas    Male   47   54777.0      No
# 12      Dallas    Male   46   62749.0      No
# 13      Dallas  Female   42   50894.0      No
# 14      Dallas  Female   61   38429.0      No
# 15      Dallas    Male   43   34074.0      No
# 16      Dallas    Male   27   50398.0      No
# 17      Dallas    Male   38   46373.0     Yes
# 18      Dallas    Male   47   51137.0      No
# ...

# %% [markdown]
# ##### Классы `City` ` Gender` и ` Illness` являются номинальным признаком, остальные признаки числовые

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['City', 'Gender', 'Illness']
# ['Age', 'Income']

# %% [markdown]
# ##### Возможные значения класса:

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# City ['Dallas' 'New York City' 'Los Angeles' 'Mountain View' 'Boston'
#  'Washington D.C.' 'San Diego' 'Austin']
# Gender ['Male' 'Female']
# Illness ['No' 'Yes']

# %% [markdown]
# ## Обрабатываем пропущенные значения
#
# Если данные содержат пропущенные значения, то имеется две простые альтернативы:
# - удалить столбцы с такими значениями (`data = data.dropna(axis = 1)`),
# - удалить строки с такими значениями (`data = data.dropna(axis = 0)`).
#
# После этого данных может стать совсем мало.
#
# Куда более эффективным (и в то же время по-прежнему простым) методом обычно является заполнение пропущенных значений для каждой количественной переменной их средним или медианным значением.
# Для категориальных признаков пропущенные значения можно заполнить самым популярным значением в столбце.

# %% [markdown]
# ##### ПРИМЕЧАНИЕ: На самом деле в нашей задаче нет пропущенных значений. Проделываем данную процедуру исключительно в тренировочных целях, чтобы отработать навык!

# %% [markdown]
# ###### Заполнение строк средними значениями:

# %%
data.median(axis = 0)
# Out:
# Number    75000.5
# Age          45.0
# Income    93655.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %% [markdown]
# ###### Проверка, что пропусков больше нет:

# %%
data[numerical_columns].count(axis = 0)
# Out:
# Age       150000
# Income    150000
# dtype: int64

# %% [markdown]
# ##### Пропуски в классах заполняем часто встречаемым значением:

# %%
data[categorical_columns].count(axis = 0)
# Out:
# City       150000
# Gender     150000
# Illness    150000
# dtype: int64

# %%
data['City'].describe()
# Out:
# count            150000
# unique                8
# top       New York City
# freq              50307
# Name: City, dtype: object

# %%
type(data['City'].describe())
# Out:
# pandas.core.series.Series

# %%
data['City'].describe().top
# Out:
# 'New York City'

# %%
data['City'] = data['City'].fillna('New York City')

# %%
data.describe(include = [object])
# Out:
#                  City  Gender Illness
# count          150000  150000  150000
# unique              8       2       2
# top     New York City    Male      No
# freq            50307   83800  137861

# %% [markdown]
# ##### Метод заполнения пропусков во всех номинальных признаках наиболее часто встречаемыми значениями:

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#                  City  Gender Illness
# count          150000  150000  150000
# unique              8       2       2
# top     New York City    Male      No
# freq            50307   83800  137861

# %% [markdown]
# ## Векторизация
#
# Нужно что-то сделать с категориальными (номинальными) признаками

# %% [markdown]
# ###### Выделение бинарных и небинарных признаков

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['Gender', 'Illness'] ['City']

# %% [markdown]
# ##### В нашей задаче есть два бинарных признака : `Gender` и `Illness`.

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data.at[data['Gender'] == 'Male', 'Gender'] = 0
data.at[data['Gender'] == 'Female', 'Gender'] = 1
data['Gender'].describe()
# Out:
# count    150000.000000
# mean          0.441333
# std           0.496548
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: Gender, dtype: float64

# %% [markdown]
# ##### Класс `Illness` будет целевым признаком.

# %%
data['City'].unique()
# Out:
# array(['Dallas', 'New York City', 'Los Angeles', 'Mountain View',
#        'Boston', 'Washington D.C.', 'San Diego', 'Austin'], dtype=object)

# %% [markdown]
# К небинарными признакам применим метод _векторизации_,
# который заключается в следующем.
#
# Признак `j`, принимающий `s` значений, заменим на `s` признаков, принимащих значения `0` или `1`,
# в зависимости от того, чему равно значение исходного признака `j`.
#
# Например, в нашей задаче признак `City` принимает 8 различных значений:

# %% [markdown]
# Заменим признак `City` 6 признаками: `Dallas`, `New York City`, ..., `Austin`.
#
#  - Если признак `City` принимает значение `Dallas`, то признак `Dallas` равен `1`, а все остальные равны `0`.
#  - Если признак `City` принимает значение `New York City`, то признак `New York City` равен `1`, а все остальные равны `0`.
#  - и т.д.
#
# ##### Такую векторизацию осуществляет в pandas метод `get_dummies`:

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['City_Austin', 'City_Boston', 'City_Dallas', 'City_Los Angeles',
#        'City_Mountain View', 'City_New York City', 'City_San Diego',
#        'City_Washington D.C.'],
#       dtype='object')

# %% [markdown]
# ## Нормализация количественных признаков
#
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных.
# К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно _нормализовать_.
# Это можно делать разными способами.
# Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                  Age         Income
# count  150000.000000  150000.000000
# mean       44.950200   91252.798273
# std        11.572486   24989.500948
# min        25.000000    -654.000000
# 25%        35.000000   80867.750000
# 50%        45.000000   93655.000000
# 75%        55.000000  104519.000000
# max        65.000000  177157.000000

# %% [markdown]
# ##### Нормализация (из значения вычитаем среднее по столбцу и делим полученное на стандартное отклонение):

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                 Age        Income
# count  1.500000e+05  1.500000e+05
# mean  -3.098492e-16  1.242429e-15
# std    1.000000e+00  1.000000e+00
# min   -1.723934e+00 -3.677816e+00
# 25%   -8.598153e-01 -4.155765e-01
# 50%    4.303311e-03  9.612844e-02
# 75%    8.684219e-01  5.308710e-01
# max    1.732540e+00  3.437612e+00

# %% [markdown]
# ## Соединяем все в одну таблицу

# %% [markdown]
# ##### Соединяем для решения нашей задачи нормализованную таблицу и выходы (класс):

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (150000, 12)

# %%
data.describe()
# Out:
#                 Age        Income    City_Austin    City_Boston  \
# count  1.500000e+05  1.500000e+05  150000.000000  150000.000000
# mean  -3.098492e-16  1.242429e-15       0.081947       0.055340
# std    1.000000e+00  1.000000e+00       0.274284       0.228643
# min   -1.723934e+00 -3.677816e+00       0.000000       0.000000
# 25%   -8.598153e-01 -4.155765e-01       0.000000       0.000000
# 50%    4.303311e-03  9.612844e-02       0.000000       0.000000
# 75%    8.684219e-01  5.308710e-01       0.000000       0.000000
# max    1.732540e+00  3.437612e+00       1.000000       1.000000
#
#          City_Dallas  City_Los Angeles  City_Mountain View  \
# count  150000.000000     150000.000000       150000.000000
# mean        0.131380          0.214487            0.094793
# std         0.337817          0.410467            0.292930
# min         0.000000          0.000000            0.000000
# 25%         0.000000          0.000000            0.000000
# ...

# %% [markdown]
# # X и y

# %%
X = data.drop(('Illness'), axis = 1) # выбрасываем столбец 'Illness'
y = data['Illness']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ##### Признаки без `Illness`:

# %%
feature_names
# Out:
# Index(['Age', 'Income', 'City_Austin', 'City_Boston', 'City_Dallas',
#        'City_Los Angeles', 'City_Mountain View', 'City_New York City',
#        'City_San Diego', 'City_Washington D.C.', 'Gender'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (150000, 11)
# (150000,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### Разбиваем выборку на обучающую и тестовую. На тест даем 30% выборки:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 105000 45000

# %%
105000 + 45000
# Out:
# 150000

# %% [markdown]
# В библиотеке scikit-learn реализована масса алгоритмов машинного обучения.
#
# #### Некоторые алгоритмы машинного обучения, реализованные в scikit-learn:
#
#  Метод                                     |  Класс
# -------------------------------------------|--------------------------------------------
#  kNN – $k$ ближайших соседей               | `sklearn.neighbors.KNeighborsClassifier`
#  LDA – линейный дискриминантный анализ     | `sklearn.discriminant_analysis.LinearDiscriminantAnalysis`
#  QDA – квадратичный дискриминантный анализ | `sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis`
#  Logistic – логистическая регрессия        | `sklearn.linear_model.LogisticRegression`
#  SVC – машина опорных векторов             | `sklearn.svm.SVC`
#  Tree – деревья решений                    | `sklearn.tree.DecisionTreeClassifier`
#  RF – случайный лес                        | `sklearn.ensemble.RandomForestClassifier`
#  ExtrRF – экстремально случайный лес       | ` `
#  AdaBoost – алгоритм AdaBoost              | `sklearn.ensemble.AdaBoostClassifier`
#  GBT – градиентный бустинг деревьев решений| `sklearn.ensemble.GradientBoostingClassifier`
#  Нейронные сети                            | ` `
#
#
#
#
# #### Основные методы классов, реализующих алгоритмы машинного обучения
# Все алгоритмы выполнены в виде классов, обладающих по крайней мере следующими методами:
#
#
#
#    Метод класса            |  Описание
#  --------------------------|-------------------------------------------------------------
#   `fit(X_train, y_train)`              |  обучение (тренировка) модели на обучающей выборке `X_train`, `y_train`
#   `predict(X)`             |  предсказание на данных `X`
#   `set_params(**params)`   |  установка параметров алгоритма
#   `get_params()`           |  чтение параметров алгоритма
#
#  Заметим, что параметры алгоритмов обучения можно задавать как в конструкторе класса, так и с помощью метода `set_params(**params)`.
#
#  #### Таблица наличия/отсутствия методов для основных алгоритмов машинного обучения:
#
#
#    Методы класса               | kNN | LDA | QDA | Logistic | SVC | Tree | RF | AdaBoost | GBT
#  ------------------------------|-----|-----|-----|----------|-----|------|----|----------|------
#   `fit(X, y)`                  |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict(X)`                 |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict_proba(X)`           |  +  |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `predict_log_proba(X)`       |     |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `score(X, y)`                |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `decision_function(X)`       |     |  +  |  +  |    +     |  +  |      |    |    +     |  +
#   `transform(X)`               |     |  +  |     |    +     |     |  +   | +  |          |  +
#   `staged_decision_function(X)`|     |     |     |          |     |      |    |    +     |  +
#   `staged_predict(X)`          |     |     |     |          |     |      |    |    +     |  +
#   `staged_predict_proba(X)`    |     |     |     |          |     |      |    |    +     |  +
#   `staged_score(X, y)`         |     |     |     |          |     |      |    |    +     |  +
#   `set_params(**params)`       |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `get_params()`               |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +

# %% [markdown]
# # $k$NN

# %% [markdown]
# ##### Используем k ближайших соседей с числом соседей равным 10

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %% [markdown]
# ##### Считаем ошибку на тесте и на обуч. выборке:

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.08130476190476191
# ошибка на тестовой выборке: 0.08004444444444445

# %% [markdown]
# ##### Строим матрицу неточности (соответствий) для наглядности совпадения предсказанных и истинных меток:

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[41398     0]
#  [ 3602     0]]

# %% [markdown]
# ###  Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10) #Подборка параметров
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print("Меньшая ошибка " + str(best_cv_err))
print("Число соседей " + str(best_n_neighbors))
# Out:
# Меньшая ошибка 0.08130476190476188
# Число соседей 10

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.08130476190476191
# ошибка на тестовой выборке: 0.08004444444444445

# %% [markdown]
# ##### Отрисуем динамику изменения ошибок в зависимости от числа соседей:

# %%
ran_k = range(1, 12)
err_train_mas = []
err_test_mas = []
for k in ran_k:
    mod_k = KNeighborsClassifier(n_neighbors = k)
    mod_k.fit(X_train, y_train)
    err_train_mas.append(np.mean(mod_k.predict(X_train) != y_train))
    err_test_mas.append(np.mean(mod_k.predict(X_test) != y_test))
plt.plot(ran_k, err_train_mas, 'r-o', label = 'Train error')
plt.plot(ran_k, err_test_mas,  'b-o', label = 'Test error')    
plt.legend(loc = 2)

# %%
np.min(err_test_mas)
# Out:
# 0.08004444444444445

# %% [markdown]
# #### С ростом числа ближайших соседей ошибка на тестовой выборке начинает уменьшаться и стабилизируется, а на тренировочной увеличивается.

# %% [markdown]
# ##### Посмотрим и другие методы:

# %% [markdown]
# # SVC

# %% [markdown]
# ##### Метод опорных векторов:

# %%
from sklearn.svm import SVC
svc = SVC(gamma = 'scale')
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.08130476190476191
# ошибка на тестовой выборке: 0.08004444444444445

# %% [markdown]
# # Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.0005523809523809524
# ошибка на тестовой выборке: 0.13457777777777777

# %%
y_test_predict = rf.predict(X_test)
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[38701  2697]
#  [ 3359   243]]

# %% [markdown]
# ### Значимость признаков

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %% [markdown]
# ##### Отображение значимости каждого признаки:

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'Income' (0.917828)
#  2. feature '  Age' (0.078511)
#  3. feature 'Gender' (0.001742)
#  4. feature 'City_Los Angeles' (0.000327)
#  5. feature 'City_New York City' (0.000304)
#  6. feature 'City_Austin' (0.000266)
#  7. feature 'City_Boston' (0.000261)
#  8. feature 'City_San Diego' (0.000256)
#  9. feature 'City_Washington D.C.' (0.000223)
# 10. feature 'City_Dallas' (0.000145)
# 11. feature 'City_Mountain View' (0.000137)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['Income', 'Age', 'Income'], dtype='object')

# %% [markdown]
# ##### Гистограмма значимости:

# %%
d_first = 11
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 11)

# %% [markdown]
# # Extremely Randomized Trees

# %% [markdown]
# ##### Еще одни рандомизированные деревья:

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.0005523809523809524
# ошибка на тестовой выборке: 0.14115555555555556

# %% [markdown]
# # AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 10)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.0812952380952381
# ошибка на тестовой выборке: 0.08004444444444445

# %% [markdown]
# # GBT

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.08028571428571428
# ошибка на тестовой выборке: 0.08097777777777777

# %% [markdown]
# # Часть №2

# %% [markdown]
# ## PCA

# %% [markdown]
# ##### Используем PCA и сокращаем размерность признаков до 2

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)
X_PCA = pca.fit_transform(X)

# %% [markdown]
# ###### Печатаем результат

# %%
X_PCA
# Out:
# array([[ 2.13013828, -0.37522802],
#        [ 1.96871646,  0.75082862],
#        [ 1.67197822, -0.28151406],
#        ...,
#        [-0.83494488, -1.62763501],
#        [-0.83602342, -1.71403996],
#        [ 0.22269907, -0.69166345]])

# %% [markdown]
# ##### Изобразим точки

# %%
plt.scatter(X_PCA[:,0], X_PCA[:,1], alpha = .2)

plt.xlabel('C1')
plt.ylabel('C2')
plt.title('Оставшиеся компоненты после РСА')
# Out:
# Text(0.5, 1.0, 'Оставшиеся компоненты после РСА')

# %% [markdown]
# #### Применяем kNN (c оптимальным значение соседей = 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_PCA, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 105000 45000

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 10).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print("ошибка на обучающей выборке: " + str(err_train)) 
print("ошибка на тестовой выборке: " + str(err_test))
# Out:
# ошибка на обучающей выборке: 0.08131428571428571
# ошибка на тестовой выборке: 0.08004444444444445

# %% [markdown]
# #### График зависимости от главных компонент

# %%
comp = range(1, 12)
err_train_mas = []
err_test_mas = []
for temp in comp:
    pca = PCA(n_components = temp)
    X_PCA = pca.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_PCA, y, test_size = 0.3, random_state = 42)
    knn = KNeighborsClassifier(n_neighbors = 20).fit(X_train, y_train)
    err_train_mas.append(np.mean(knn.predict(X_train) != y_train))
    err_test_mas.append(np.mean(knn.predict(X_test) != y_test))
plt.plot(comp, err_train_mas, 'r-o', label = 'Train error')
plt.plot(comp, err_test_mas,  'b-o', label = 'Test error')    
plt.legend(loc = 2)

# %% [markdown]
# Из графиков видно, что ошибка постоянно находится на одном уровне, а также видно, что величина ее не отличается от результата, полученного до применения метода главных компонент. Делая вывод можно сказать, что в данном случае PCA не позволил уменьшить ошибку.

# %%
np.min(err_test_mas)
# Out:
# 0.08004444444444445

# %%
np.min(err_train_mas)
# Out:
# 0.08130476190476191

# %% [markdown]
# # Часть №3

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
N_test, _ = X_test.shape

# %% [markdown]
# Обучаем классификатор.

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
print('Train error: {}, Test error: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train error: 0.08130476190476191, Test error: 0.08004444444444445

# %% [markdown]
# Теперь использовуем двухслойную полносвязную сеть:

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100, 2), solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
print('Train error: {}, Test error: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train error: 0.08130476190476191, Test error: 0.08004444444444445

# %% [markdown]
# Качество на обеих выборках осталось без изменений.

# %% [markdown]
# ### Подбор гиперпараметров ($\alpha$)

# %% [markdown]
# Подберем оптимальное значение параметра регуляризации 𝛼

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.semilogx(alpha_arr, train_err, 'r-o', label = 'Train')
plt.semilogx(alpha_arr, test_err, 'b-o', label = 'Test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()

# %% [markdown]
# Видно, что ошибка на тренировочной и на тестовой выборках постоянна при любом $\alpha$ и колеблется в районе 8%.

# %% [markdown]
# Классификатор при найденном оптимальном значении $\alpha$:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
alpha_opt = alpha_arr[test_err == min_test_err][0]

print('Min train error: {}, \tMin test error: {}'.format(min_train_err, min_test_err))
print('Alpha: ', alpha_opt)
# Out:
# Min train error: 0.08130476190476191, 	Min test error: 0.08004444444444445
# Alpha:  0.001

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (100, 50),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print('Train error: {}, Test error: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train error: 0.08130476190476191, Test error: 0.08004444444444445

# %% [markdown]
# ### Подберем оптимальное количество нейронов:
# #### (на 1 скрытом слое)

# %%
neurons_arr = np.arange(10,150, 5)
test_err = []
train_err = []
for neuron in neurons_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron, 50), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(neurons_arr, train_err, 'r-o', label = 'Train')
plt.semilogx(neurons_arr, test_err, 'b-o', label = 'Test')
plt.xlim([np.max(neurons_arr), np.min(neurons_arr)])
plt.title('Error vs. neuron')
plt.xlabel('neuron')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Как на тренировочной, так и на тестовой выборках ошибка по прежнему ведет себя по-разному при любом количестве нейронов.

# %% [markdown]
# Классификатор при найденном оптимальном значении количества нейронов:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
neuron_opt = neurons_arr[test_err == min_test_err][0]

print('Min train error: {}, \tMin test error: {}'.format(min_train_err, min_test_err))
print('Neuron: ', neuron_opt)
# Out:
# Min train error: 0.08130476190476191, 	Min test error: 0.08004444444444445
# Neuron:  10

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron_opt, 50),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print('Train error: {}, Test error: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train error: 0.08130476190476191, Test error: 0.08004444444444445

# %% [markdown]
# # Random forests.

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0005523809523809524 0.13473333333333334

# %%
trees_arr = np.arange(500, 1000, 100)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier(n_estimators = trees, oob_score=True)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)
plt.plot(trees_arr, train_err, 'r-o', label = 'Train')
plt.plot(trees_arr, test_err, 'b-o', label = 'Test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()

# %%
err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0005523809523809524 0.13473333333333334

# %% [markdown]
# # Gradient Boosted Trees

# %%
from sklearn.ensemble import GradientBoostingClassifier

estiamtors = np.arange(1000,1500, 100)
test_err = []
train_err = []
for estimator in estiamtors:
    gbt = GradientBoostingClassifier(n_estimators = estimator, random_state = 42)
    gbt.fit(X_train, y_train)

    y_train_pred = gbt.predict(X_train)
    y_test_pred = gbt.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
plt.semilogx(estiamtors, train_err, 'r-o', label = 'Train')
plt.semilogx(estiamtors, test_err, 'b-o', label = 'Test')
plt.xlim([np.max(estiamtors), np.min(estiamtors)])
plt.title('Error vs. Number of trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %%
trees_arr = np.arange(1,2000, 100)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))
plt.plot(trees_arr, train_err, 'r-o', label = 'Train')
plt.plot(trees_arr, test_err, 'b-o', label = 'Test')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. Number of trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()

# %% [markdown]
# С ростом числа деревьев наблюдается рост тестовой ошибки и снишение тренировочной. Видно переобучение.

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print('Min train error: {}, \tMin test error: {}'.format(min_train_err, min_test_err))
# Out:
# Min train error: 0.07974285714285714, 	Min test error: 0.08097777777777777

# %% [markdown]
# # Итог

# %% [markdown]
# Сделаем выводы. На данном датасете, при использовании метода k ближайших соседей удалось получить минимальную ошибку, при использовании метода k ближайших соседей после применения метода главных компонент результат не изменился. Метод Random Forest показал минимульную ошибку на обучающей выборке, на тестовой же выборке результаты полученные с помощью него самые худшие.
#  В датасете присутвуют несколько слабоинформативных признаков, и даже после уменьшения их числа эффективность модели не на много повысилась.
